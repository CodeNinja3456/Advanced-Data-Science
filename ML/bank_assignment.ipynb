# %%
import pandas
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#label encoding:process of converting one data type to another
#float(number),string/object(text)
data=pandas.read_csv('datasets/bank_full.csv')
data
# Out:
#        age              job  marital            education  default housing  \
# 0       56        housemaid  married             basic.4y       no      no
# 1       57         services  married          high.school  unknown      no
# 2       37         services  married          high.school       no     yes
# 3       40           admin.  married             basic.6y       no      no
# 4       56         services  married          high.school       no      no
# ...    ...              ...      ...                  ...      ...     ...
# 41183   73          retired  married  professional.course       no     yes
# 41184   46  blue+AC0-collar  married  professional.course       no      no
# 41185   56          retired  married    university.degree       no     yes
# 41186   44       technician  married  professional.course       no      no
# 41187   74          retired  married  professional.course       no     yes
#
# ...

# %%
data.drop(['duration'], axis=1, inplace=True)

# %%
data.isnull().sum()
# Out:
# age           0
# job           5
# marital       9
# education     0
# default       0
# housing       0
# loan          4
# contact       0
# month         0
# day_week      0
# campaign      0
# previous      0
# poutcome      0
# subscribed    0
# dtype: int64

# %%
data['job'].fillna('unknown',inplace=True)
data['marital'].fillna('unknown',inplace=True)
data['loan'].fillna('unknown',inplace=True)

data.isnull().sum()
# Out:
# /tmp/ipykernel_2857/1952570253.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['job'].fillna('unknown',inplace=True)
# /tmp/ipykernel_2857/1952570253.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
#job label encoding
#step1: groupby to see the different jobs we have
data.groupby('job').size()
# Out:
# job
# admin.               10422
# blue+AC0-collar       9253
# entrepreneur          1456
# housemaid             1060
# management            2924
# retired               1720
# self+AC0-employed     1421
# services              3967
# student                875
# technician            6741
# unemployed            1014
# unknown                335
# dtype: int64

# %%
#Encoding
#In python we use replace() function to encode
data['job'].replace({
    'admin.':1,
    'blue+AC0-collar':2,
    'entrepreneur':3,
    'housemaid' :4,           
    'management':5,            
    'retired' :6,              
    'self+AC0-employed' :7,    
    'services' :8,             
    'student' :9,               
    'technician' :10,          
    'unemployed' :11,           
    'unknown' :12,               
    },inplace=True)

data.groupby('job').size()
# Out:
# /tmp/ipykernel_2857/60822522.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['job'].replace({
# job
# 1     10422
# 2      9253
# 3      1456
# 4      1060
# 5      2924
# 6      1720
# 7      1421
# 8      3967
# 9       875
# 10     6741
# 11     1014
# 12      335
# dtype: int64

# %%
data['marital'].replace({
    'divorced' :  1,
    'married'  :  2,
    'single'   :  3,
    'unknown'  :  4,

},inplace=True)

data.groupby('marital').size()
# Out:
# /tmp/ipykernel_2857/2808993599.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['marital'].replace({
# marital
# 1     4612
# 2    24919
# 3    11568
# 4       89
# dtype: int64

# %%
data['education'].replace({
    'basic.4y' :                1,
    'basic.6y'  :               2,
    'basic.9y'   :              3,
    'high.school' :             4,
    'illiterate'  :             5,
    'professional.course' :     6,
    'university.degree' :       7,
    'unknown'  :                8,    
    },inplace=True)
data.groupby('education').size()
# Out:
# /tmp/ipykernel_2857/398167180.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['education'].replace({
# /tmp/ipykernel_2857/398167180.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['education'].replace({
# education
# 1     4176
# 2     2292
# 3     6045
# 4     9515
# ...

# %%
data['default'].replace({
    'no' :  1,
    'unknown'  :  2,
    'yes'   :  3,
   
},inplace=True)
data.groupby('default').size()
# Out:
# /tmp/ipykernel_2857/1233768468.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['default'].replace({
# /tmp/ipykernel_2857/1233768468.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['default'].replace({
# default
# 1    32588
# 2     8597
# 3        3
# dtype: int64

# %%
data['housing'].replace({
    'no' :  1,
    'unknown'  :  2,
    'yes'   :  3,
   
},inplace=True)
data.groupby('housing').size()
# Out:
# /tmp/ipykernel_2857/780328292.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['housing'].replace({
# /tmp/ipykernel_2857/780328292.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['housing'].replace({
# housing
# 1    18622
# 2      990
# 3    21576
# dtype: int64

# %%
data.groupby('loan').size()
data['loan'].replace({
    'no' :  1,
    'unknown'  :  2,
    'yes'   :  3,
   
},inplace=True)
data.groupby('loan').size()
# Out:
# /tmp/ipykernel_2857/3675326767.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['loan'].replace({
# loan
# 1    33947
# 2      994
# 3     6247
# dtype: int64

# %%
data['contact'].replace({
    'cellular' :    1,
    'telephone':    2,
   
},inplace=True)
data.groupby('contact').size()
# Out:
# /tmp/ipykernel_2857/1746204588.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['contact'].replace({
# /tmp/ipykernel_2857/1746204588.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['contact'].replace({
# contact
# 1    26144
# 2    15044
# dtype: int64

# %%
data['month'].replace({
    'apr' :    1,
    'aug' :    2,
    'dec'  :   3,
    'jul'  :   4,
    'jun'  :   5,
    'mar'  :   6,
    'may'   :  7,
    'nov'   :  8,
    'oct'   :  9,
    'sep'  :   10,
   
},inplace=True)
data.groupby('month').size()
# Out:
# /tmp/ipykernel_2857/391170968.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['month'].replace({
# /tmp/ipykernel_2857/391170968.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['month'].replace({
# month
# 1      2632
# 2      6178
# 3       182
# 4      7174
# ...

# %%
data['day_week'].replace({
    'fri'  :  1,
    'mon'  :  2,
    'thu'  :  3,
    'tue'  :  4,
    'wed'  :  5,
   
},inplace=True)
data.groupby('day_week').size()
# Out:
# /tmp/ipykernel_2857/2963122986.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['day_week'].replace({
# /tmp/ipykernel_2857/2963122986.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['day_week'].replace({
# day_week
# 1    7827
# 2    8514
# 3    8623
# 4    8090
# ...

# %%
data['poutcome'].replace({
    'failure' :       1,
    'nonexistent':    2,
    'success' :       3,
   
},inplace=True)
data.groupby('poutcome').size()
# Out:
# /tmp/ipykernel_2857/2958842183.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['poutcome'].replace({
# /tmp/ipykernel_2857/2958842183.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['poutcome'].replace({
# poutcome
# 1     4252
# 2    35563
# 3     1373
# dtype: int64

# %%
array=data.values

X=array[0:41190,1:13]
X
Y=array[0:41190,13]
Y
# Out:
# array(['no', 'no', 'no', ..., 'no', 'yes', 'no'], dtype=object)

# %%
from sklearn import model_selection
x_train,x_test,y_train,y_test=model_selection.train_test_split(X,Y,test_size=0.3,random_state=42)
y_train
x_test
# Out:
# array([[10, 2, 4, ..., 1, 1, 1],
#        [12, 2, 8, ..., 2, 0, 2],
#        [2, 2, 3, ..., 1, 1, 1],
#        ...,
#        [2, 3, 4, ..., 2, 0, 2],
#        [10, 1, 6, ..., 3, 0, 2],
#        [10, 2, 7, ..., 2, 1, 1]], dtype=object)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
prediction=model.predict(x_test)
print('The algorithm has predicted',prediction)
print('The actual answers are',y_test)
# Out:
# The algorithm has predicted ['no' 'no' 'no' ... 'no' 'no' 'no']
# The actual answers are ['no' 'no' 'no' ... 'no' 'no' 'no']

# %%
from sklearn.metrics import accuracy_score
check_accuracy=accuracy_score(prediction,y_test)*100
check_accuracy
# Out:
# 88.27385287691187

# %%
# Imports Classification Models
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC

# Create an Empty List and append all models, Give the Models an alias Name
# i.e we called KNeighborsClassifier() alias KNC etc
models = []
models.append(('D Trees', DecisionTreeClassifier()))
models.append(('Gaussian', GaussianNB()))
models.append(('KNC', KNeighborsClassifier()))
models.append(('Random Forest', RandomForestClassifier()))
models.append(('Gradient Boosting', GradientBoostingClassifier()))
models.append(('Linear Disc', LinearDiscriminantAnalysis()))
models.append(('Support Machines', SVC(gamma = 'auto')))

# Import Cross Validation and KFOLD
from sklearn.model_selection import cross_val_score, KFold
# Create a for loop so that each model is tested in turn
for name, model in models:
            # Here we do a 10 split K-FOLD
            kfold = KFold(n_splits = 10, random_state=42, shuffle=True)

            # We get the results for each Fold
            cv_results = cross_val_score(model, x_train, y_train, cv = kfold,
            scoring='accuracy')

            # Get the average of all Folds
            print(name, ' Results:= ', cv_results.mean())
# Out:
# D Trees  Results:=  0.8456521875088698
# Gaussian  Results:=  0.8368771236811708
# KNC  Results:=  0.8878293194165616
# Random Forest  Results:=  0.883042566712995
# Gradient Boosting  Results:=  0.8979225629413035
# Linear Disc  Results:=  0.8965352516040515
